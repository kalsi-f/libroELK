# %% [markdown]
# # Trabajando con ELK
#
# Una vez hecho todo lo del paso anterior estamos listos para trabajar en Kibana

# %% [markdown]
# ### Creamos un Data view
#
# Vamos a Kibana
# 1. Stack Management
# 2. Data Views
# 3. Create Data View
#
# ![StackManagment](imagenes/1.jpg)
#
# ![Data views](imagenes/2.jpg)
#
# ![Create](imagenes/3.jpg)
